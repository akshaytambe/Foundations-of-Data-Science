# %% [markdown]
# # Foundations of Data Science
# ## Homework 2

# %% [markdown]
# Student Name: Akshay Prakash Tambe
#
# Student Netid: apt321
# ***

# %% [markdown]
# ### Part 1: Case study
# - Read [this article](http://www.nytimes.com/2012/02/19/magazine/shopping-habits.html) in the New York Times.
# - Use what we've learned in class and from the book to describe how one could set Target's problem up as a predictive modeling problem, such that they could have gotten the results that they did.  Formulate your solution as a proposed plan using our data science terminology.  Include aspects of the Data Science Workflow that you see as relevant to solving the problem.  Be precise but concise.

# %% [markdown]
# The 21st Century runs their businesses by focussing mainly on behavioral research. Target is the major retailer, from grocery chains to departmental products where their main goal is convincing customers that the only store they need is this store.
#
# The primary goal of Target is "Customer Retention" where they want to attract customers by luring them using discounts and promotions. As per Pole's Research, it is necessary to track down the customer's habits and by having this knowledge, we can add the product to their routines and thus, change their shopping habits.
#
# As phases in life changes, people change their shopping habits. Target wanted to focus mainly on Pregnant Customers as a new parent's buying habits are suddenly in flux. Hence, they wanted to identify such customers when the women in their second trimester where they begin buying all sorts of new things. After identifying they can design discounts and promotions as per their relevant shopping habits, exclusively for such customers.
#
# Defining the Problem using *Data Science Terminology*:
# ** Problem: ** Increase Target's Market Cap by identifying accurately when is the potential customer going to enter the trimester of pregnancy.
#
# ** Goal: ** Determine when will the women potentially enter the trimester of the pregnancy.
#
# ** Motivation: ** Target to-be Parents by making them buy baby products, Medicare, and other primary products by understanding their buying patterns.
#
# ** Type of Modelling Used by Pole's Team: ** Predictive Modelling
#
# ** Data Loading - How can data be collected: **
# - Shopping history tracking by using Target's Unique Customer Identification Number
# - Data from online shopping
# - Purchases associated with a particular payment method (Credit Card, Debit Card and other payment methods)
# - As the data is public (As stated in the article), data can be bought from multiple sources having data about  customer's ethnicity, age group, job history, magazines read, bankruptcy or marital status, property transactions, education history, online interests, daily product preferences, political leanings, reading habits, charitable giving and ownership of number of cars.
#
# ** Data Transformation - Merging the data: **
# - Before working on the dataset, the collected data should be in a single format
# - Joining tables according to Customer Name, Unique Identification, Payment Method Information can be done to aggregate the data in a single large table.
#
# ** Data Cleaning and Exploration - Identifying the data which is necessary for Prediction Model: **
# ** Data Cleaning: **
# - Eliminate unnecessary, irrelevant and duplicate data records.
# - Clean the data by adjusting the missing values (Techniques like Gaussian Distribution, Taking Mean if data is numeric can be used)
#
# ** Data Exploration: **
# - Marital Status: A married couple is likely to have a baby.
# - Age Group: A women in age groups of the 20s or early 30s are likely to get pregnant. A woman's fertility starts to decline in her early 30s, with the decline speeding up after 35. At 40 a woman only has a 5% chance of becoming pregnant in any month.
# - Online Interest: Tracking customer's online interest, reading habits and online orders such as Medicare and foods to eat during the pregnancy. This will boost the model identifying the “pregnancy prediction” score.
# - Daily Product Preferences: Tracking Customer's daily shopping products can be used to create association rules.
#
# ** Feature Engineering: **
# - New features like reorder frequency of a particular product can be derived from the available data which will help us determine the buying pattern of the customer.
# - Identifying a change in shopping pattern (purchase or lack of purchase) by checking a different set of orders by a customer particularly required for a pregnant woman (Deviation in Regular Shopping pattern). Items like a body pillow, BPA free water bottle, prenatal vitamins, prenatal DHA, peppermint tea, Maternity wear, Sleep aids, Pregnancy books, Newborn clothes, Crib and mattress, and much more pregnancy-related products can be bought by a customer frequently. This ordering pattern will help to create association rules to predict the goal.
# - After identifying all the necessary features for analysis, we can eliminate weak entities by using data reduction techniques for better decision making. Techniques like Principal Component Analysis, High Correlation Filter, Low Variance Filter can be helpful in this process.
#
# ** Data Modelling, Performance Evaluation, and Model Selection: **
# - The data needs to be split into test and train data as per the decided split ratios (70:30 can be good split for modeling). The test data can be further used for calculating the accuracy of the model. Tfid can be used for tokenizing and counting
# - Modeling techniques such as Logistic Regression, Support Vector Machines, Random Forest and XGBoost Models can be run against the training dataset. SVM (non-probabilistic binary linear classifier) and XGBoost Modelling can be better in this case as we can have predictions in binary format.
# - A feature importance matrix and accuracy score will play a major role in performance evaluation and model selection.
# - Performance Evaluation can be done by comparing the training dataset with the test data and calculate the accuracy.
# - After performance evaluation and checking which model correcting fits the data, we can determine the best model for the given dataset and run predictions using that model.
#
# ** Prediction: **
# - Target Variable: To determine whether a woman is pregnant or not. (YES/NO)
# - We can run the model of a new test data to get a “pregnancy prediction” score. A threshold level should be set to eliminate weak predictions.
# - The Prediction Score will mostly depend on the buying order of pregnancy-related products, a sudden change in buying pattern, prolonged pregnancy-related activity.
#
#
# ** Association Rules: **
# - As Target is a major retailer for almost all everyday products, association rules can be created for a pregnant woman to buy other frequently associated products.
# - A famous technique called "Market Basket Analysis" can be done which will help to identify relevant products using association rules.
# - The above analysis can be used to create discount and promotions to the customers by bundling the coupons along with some other frequently associated products.
#
# Finally, Target can send out discounts and promotions to the selected customers through email or appending at the end of the receipt for the future purchase. Also, it can keep a track of usage of coupons and then again can send further rewards to the customers who are using it.
#
# The application of predictive modeling was a great success for Target because along with the analysis of customer buying patterns, they also researched on Scientific study of habitual systems (Cue-Routine-Reward).

# %% [markdown]
# ### Part 2: Exploring data in the command line
# For this part we will be using the data file located in `"data/advertising_events.csv"`. This file consists of records that pertain to some online advertising events on a given day. There are 4 comma separated columns in this order: `userid`, `timestamp`, `domain`, and `action`. These fields are of type `int` (continuous), `int` (continuous), `string`, and `int` (category) respectively. Answer the following questions using Linux/Unix bash commands. All questions can be answered in one line (sometimes, with pipes)! Some questions will have many possible solutions. Don't forget that in IPython notebooks you must prefix all bash commands with an exclamation point, i.e. `"!command arguments"`.
#
# [Hints: You can experiment with whatever you want in the notebook and then delete things to construct your answer later.  Recall that once you enter the "!" then filename completion should work.]

# %% [markdown]
# 1\. How many records (lines) are in this file?

# %%
# wordcount by line - 10341 Records
# !wc -l < advertising_events.csv
# Out:
#    10341

# %% [markdown]
# 2\. How many unique users are in this file? (hint: consider the 'cut' command and use pipe operator '|')

# %%
# cut command for taking 1st column --> sort unique --> wordcount by line - 732 Unique Users
# !cut -d ',' -f 1 advertising_events.csv | sort -u | wc -l
# Out:
#      732

# %% [markdown]
# 3\. Rank all domains by the number of visits they received in descending order. (hint: consider the 'cut', 'uniq' and 'sort' commands and the pipe operator).

# %%
# cut command for taking 3rd column --> sort by domain --> take unique domain count --> sort in descending order
# !cut -d ',' -f 3 advertising_events.csv | sort | uniq -c | sort -r
# Out:
# 3114 google.com
# 2092 facebook.com
# 1036 youtube.com
# 1034 yahoo.com
# 1022 baidu.com
#  513 wikipedia.org
#  511 amazon.com
#  382 qq.com
#  321 twitter.com
#  316 taobao.com

# %% [markdown]
# 4\. List all records for the user with user id 37. (hint: this can be done using 'grep')

# %%
# global regex for user id 37
# !grep -w '37' advertising_events.csv
# Out:
# 37,648061658,google.com,0
# 37,642479972,google.com,2
# 37,644493341,facebook.com,2
# 37,654941318,facebook.com,1
# 37,649979874,baidu.com,1
# 37,653061949,yahoo.com,1
# 37,655020469,google.com,3
# 37,640878012,amazon.com,0
# 37,659864136,youtube.com,1
# 37,640361378,yahoo.com,1
# 37,653862134,facebook.com,0
# 37,648828970,youtube.com,0

# %% [markdown]
# ### Part 3: Dealing with data Pythonically

# %%
# Importing Packages
import pandas as pd
import numpy as np

# %% [markdown]
# 1\. Load the data set `"datasets/ads_dataset.tsv"` into a Python Pandas data frame called `ads`.

# %%
# Loading Tab Delimited Data using read_table pandas function in 'ads' dataframe
ads = pd.read_table("ads_dataset.tsv")
ads
# Out:
#      isbuyer  buy_freq  visit_freq  buy_interval  sv_interval  \
# NaN        0       NaN           1           0.0     0.000000
# NaN        0       NaN           1           0.0     0.000000
# NaN        0       NaN           1           0.0     0.000000
# NaN        0       NaN           1           0.0     0.000000
# NaN        0       NaN           2           0.0     0.500000
# NaN        0       NaN           1           0.0     0.000000
# NaN        0       NaN           1           0.0     0.000000
# NaN        0       NaN           2           0.0    29.791670
# NaN        0       NaN           3           0.0    45.479170
# NaN        0       NaN           1           0.0     0.000000
# NaN        1       1.0           2           0.0     0.958333
# NaN        0       NaN           2           0.0    21.333330
# NaN        0       NaN           1           0.0     0.000000
# NaN        0       NaN           1           0.0     0.000000
# ...

# %% [markdown]
# 2\. Write a Python function called `getDfSummary()` that does the following:
# - Takes as input a data frame
# - For each variable in the data frame calculates the following features:
#   - `number_nan` to count the number of missing not-a-number values
#   - Ignoring missing, NA, and Null values:
#     - `number_distinct` to count the number of distinct values a variable can take on
#     - `mean`, `max`, `min`, `std` (standard deviation), and `25%`, `50%`, `75%` to correspond to the appropriate percentiles
# - All of these new features should be loaded in a new data frame. Each row of the data frame should be a variable from the input data frame, and the columns should be the new summary features.
# - Returns this new data frame containing all of the summary information
#
# Hint: The pandas `describe()` [(manual page)](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.describe.html) method returns a useful series of values that can be used here.

# %%
def getDfSummary(input_data):
    # Initialising lists
    number_nan = [] #count the number of missing not-a-number values
    number_distinct = [] #count the number of distinct values a variable can take on
    describe = [] #mean, max, min, std (standard deviation), and 25%, 50%, 75% to correspond to the appropriate percentiles
    
    # number_nan --> isnull() to check if value is null (T/F) --> sum() to count True Values
    number_nan = input_data.isnull().sum()
    
    # number_distinct --> number of unique elements in the group --> Remove missing values
    number_distinct = input_data.nunique(dropna=True)
    
    """
    describe --> using describe(): descriptive statistics that summarize the central tendency, 
    dispersion and shape of a dataset’s distribution, excluding NaN values. --> .T: fitting precisely
    """
    describe = input_data.describe().T
    
    # Loading calculated values in a new dataframe
    output_data = pd.DataFrame({'number_nan':number_nan, 'number_distinct':number_distinct, 'mean':describe['mean'],
                               'max':describe['max'], 'min':describe['min'], 'std':describe['std'], '25%':describe['25%'],
                               '50%':describe['50%'], '75%':describe['75%']})
    # Ordering Columns
    output_data = output_data[['number_nan','number_distinct', 'mean', 'max', 'min', 'std', '25%', '50%', '75%']]
    
    return output_data

# Displaying output
getDfSummary(ads)
# Out:
#                      number_nan  number_distinct        mean          max  \
# isbuyer                       0                2    0.042632      1.00000
# buy_freq                  52257               10    1.240653     15.00000
# visit_freq                    0               64    1.852777     84.00000
# buy_interval                  0              295    0.210008    174.62500
# sv_interval                   0             5886    5.825610    184.91670
# expected_time_buy             0              348   -0.198040     84.28571
# expected_time_visit           0            15135  -10.210786     91.40192
# last_buy                      0              189   64.729335    188.00000
# last_visit                    0              189   64.729335    188.00000
# multiple_buy                  0                2    0.006357      1.00000
# multiple_visit                0                2    0.277444      1.00000
# uniq_urls                     0              207   86.569343    206.00000
# ...

# %% [markdown]
# 3\. How long does it take for your `getDfSummary()` function to work on your `ads` data frame? Show us the results below.
#
# Hint: `%timeit getDfSummary(ads)`

# %%
# Calculate time for above cell code
# %timeit getDfSummary(ads)
# Out:
# 65.1 ms ± 6.56 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# 4\. Using the results returned from `getDfSummary()`, which fields, if any, contain missing `NaN` values?

# %%
# Generating Fields which contain missing NaN values
results = getDfSummary(ads)
missing_NaN = results.index[results['number_nan'] != 0].tolist()
missing_NaN
# Out:
# ['buy_freq']

# %% [markdown]
# 5\. For the fields with missing values, does it look like the data is missing at random? Are there any other fields that correlate perfectly, or predict that the data is missing? What would be an appropriate method for filling in missing values?
#
# Hint: create another data frame that has just the records with a missing value. Get a summary of this data frame using `getDfSummary()` and compare the differences. Do some feature distributions change dramatically?

# %%
# Place your code and response here

# %% [markdown]
# 6\. Which variables are binary?

# %%
# Place your code here
